# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":["rohan","seema","mahesh","shruti"],
    "marks":[9,55,67,98],
    "city":["Delhi","Jaipur","Rampur","Barilly"]
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks     city
# 0   rohan      9    Delhi
# 1   seema     55   Jaipur
# 2  mahesh     67   Rampur
# 3  shruti     98  Barilly

# %%
df.index=[1,2,3,4]

# %%
df
# Out:
#      name  marks     city
# 1   rohan      9    Delhi
# 2   seema     55   Jaipur
# 3  mahesh     67   Rampur
# 4  shruti     98  Barilly

# %%
ser=pd.Series(np.random.rand(20))

# %%
ser
# Out:
# 0     0.453036
# 1     0.704253
# 2     0.179758
# 3     0.178317
# 4     0.736895
# 5     0.443571
# 6     0.022517
# 7     0.159689
# 8     0.793434
# 9     0.307405
# 10    0.260153
# 11    0.816471
# 12    0.941210
# 13    0.834358
# 14    0.240468
# 15    0.461229
# 16    0.753455
# 17    0.308291
# 18    0.197169
# 19    0.682983
# dtype: float64

# %%
type(ser)
# Out:
# pandas.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.221094  0.554259  0.667092  0.648521  0.708222
# 1    0.210579  0.380194  0.622622  0.955193  0.587960
# 2    0.326234  0.879394  0.169751  0.285889  0.564456
# 3    0.216694  0.096841  0.537928  0.953813  0.205069
# 4    0.283239  0.228331  0.374211  0.884621  0.064944
# ..        ...       ...       ...       ...       ...
# 329  0.174038  0.082193  0.311351  0.968462  0.690404
# 330  0.255900  0.349866  0.135042  0.358455  0.237789
# 331  0.769272  0.510096  0.742856  0.263615  0.572553
# 332  0.412434  0.906842  0.787906  0.572784  0.233167
# 333  0.105311  0.925519  0.949635  0.681993  0.821828
#
# [334 rows x 5 columns]

# %%
newdf.head(3)
# Out:
#           0         1         2         3         4
# 0  0.221094  0.554259  0.667092  0.648521  0.708222
# 1  0.210579  0.380194  0.622622  0.955193  0.587960
# 2  0.326234  0.879394  0.169751  0.285889  0.564456

# %%
newdf.tail(3)
# Out:
#             0         1         2         3         4
# 331  0.769272  0.510096  0.742856  0.263615  0.572553
# 332  0.412434  0.906842  0.787906  0.572784  0.233167
# 333  0.105311  0.925519  0.949635  0.681993  0.821828

# %%
newdf.sort_index(axis=0)
# Out:
#             0         1         2         3         4
# 0    0.221094  0.554259  0.667092  0.648521  0.708222
# 1    0.210579  0.380194  0.622622  0.955193  0.587960
# 2    0.326234  0.879394  0.169751  0.285889  0.564456
# 3    0.216694  0.096841  0.537928  0.953813  0.205069
# 4    0.283239  0.228331  0.374211  0.884621  0.064944
# ..        ...       ...       ...       ...       ...
# 329  0.174038  0.082193  0.311351  0.968462  0.690404
# 330  0.255900  0.349866  0.135042  0.358455  0.237789
# 331  0.769272  0.510096  0.742856  0.263615  0.572553
# 332  0.412434  0.906842  0.787906  0.572784  0.233167
# 333  0.105311  0.925519  0.949635  0.681993  0.821828
#
# [334 rows x 5 columns]

# %%
newdf.drop(0,axis=1)
# Out:
#             1         2         3         4
# 0    0.554259  0.667092  0.648521  0.708222
# 1    0.380194  0.622622  0.955193  0.587960
# 2    0.879394  0.169751  0.285889  0.564456
# 3    0.096841  0.537928  0.953813  0.205069
# 4    0.228331  0.374211  0.884621  0.064944
# ..        ...       ...       ...       ...
# 329  0.082193  0.311351  0.968462  0.690404
# 330  0.349866  0.135042  0.358455  0.237789
# 331  0.510096  0.742856  0.263615  0.572553
# 332  0.906842  0.787906  0.572784  0.233167
# 333  0.925519  0.949635  0.681993  0.821828
#
# [334 rows x 4 columns]

# %%
newdf.dropna(inplace=True)
